# %% [markdown]
# ### Ejercicio 0
# Importa los paquetes y módulos que necesites a lo largo del notebook

# %%
# %matplotlib inline
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns

# %% [markdown]
# ### Ejercicio 1
# Construye la siguiente figura con dos subplots utilizando el estilo MATLAB (es decir plt.<funcion>, no usando objetos Axes)

# %%
fig = plt.figure()
ax = plt.axes()

x=np.linspace(0,10,100)
ax.plot(x,np.sin(x));
plt.title(r"Seno")
plt.xticks(np.arange(0, 10.1, 2.5)) 
plt.gca().xaxis.set_major_formatter('{x:.1f}') 


fig = plt.figure()
ax = plt.axes()

x=np.linspace(0,10,100)
ax.plot(x,np.cos(x));
plt.title(r"Coseno")
plt.xticks(np.arange(0, 10.1, 2.5)) 
plt.gca().xaxis.set_major_formatter('{x:.1f}')

# %% [markdown]
# ### Ejercicio 2
#
# Reproduce la imagen de la figura usando tres subplots en una columna, utilizando objetos Axes. Las dos primeras son las funciones anteriores y la tercera es la tangente (np.tan)

# %%
# Configuración inicial
x = np.linspace(0, 10, 500)  # 500 puntos para suavizar curvas

# Crear figura con 3 subplots en columna
fig, axs = plt.subplots(3, 1, figsize=(8, 10), sharex=True)

# Gráfico 1: Seno
axs[0].plot(x, np.sin(x), color='red', linewidth=2)
axs[0].set_ylabel('Seno', fontsize=12)
axs[0].set_ylim(-1.1, 1.1)  # Límites del eje y
axs[0].grid(linestyle='--', alpha=0.5)

# Gráfico 2: Coseno 
axs[1].plot(x, np.cos(x), color='green', linewidth=2)
axs[1].set_ylabel('Coseno', fontsize=12)
axs[1].set_ylim(-1.1, 1.1)
axs[1].grid(linestyle='--', alpha=0.5)

# Gráfico 3: Tangente 
axs[2].plot(x, np.tan(x), color='blue', linewidth=2)
axs[2].set_ylabel('Tangente', fontsize=12)
axs[2].set_ylim(-40, 20)  # Ajuste para valores extremos
axs[2].set_xlabel('x', fontsize=12)
axs[2].grid(linestyle='--', alpha=0.5)

# %% [markdown]
# ### Ejercicio 3: Ajuste de Colores y Estilos de Línea
#
# Modifica la primera figura para que se muestre de la siguiente maner

# %%
import matplotlib.pyplot as plt
import numpy as np


plt.figure(figsize=(12, 8))

# Figura 1
plt.subplot(2, 2, 1)
x = np.linspace(0, 10, 100)
y = np.sin(x)
plt.plot(x, y, color='purple', linestyle=':', linewidth=2)
plt.grid(True)

# Figura 2
plt.subplot(2, 2, 2)
x = np.linspace(0, 10, 100)
y = np.cos(x)
plt.plot(x, y, color='green', linestyle=':', linewidth=2.5)
plt.grid(True)

# %% [markdown]
# ### Ejercicio 4: Ajuste de Colores y Estilos de Línea.
#
# Reproduce la figura siguiente. Recuerda que las funciones seno hiperbólico y coseno hiperbólico se obtienen así:
#
# np.sinh, seno hiperbólico;
# np.cosh, coseno hiperbólico;

# %%
plt.figure(figsize=(18, 2))
# Crear datos
x = np.linspace(0, 10, 10000)
sinh = np.sinh(x)

# Primer gráfico: Seno Hiperbólico
plt.subplot(1, 2, 1)  # 1 fila, 2 columnas, posición 1
plt.plot(x, sinh, color='blue', linewidth=2)
plt.title('Seno Hiperbólico', fontsize=14)
plt.xlabel('x', fontsize=12)
plt.ylabel('sinh(x)', fontsize=12)
plt.grid(True, linestyle='--', alpha=0.7)


plt.figure(figsize=(18, 2))
# Crear datos
x = np.linspace(0, 10, 10000)
cosh = np.cosh(x)

# Segundo gráfico: Coseno Hiperbólico
plt.subplot(1, 2, 2)  # 1 fila, 2 columnas, posición 2
plt.plot(x, cosh, color='red', linewidth=2)
plt.title('Coseno Hiperbólico', fontsize=14)
plt.xlabel('x', fontsize=12)
plt.ylabel('cosh(x)', fontsize=12)
plt.grid(True, linestyle='--', alpha=0.7)

# %% [markdown]
# ### Ejercicio 5: Ajustando el Espaciado de Subplots

# %% [markdown]
# Reproduce la siguiente figura con cuatro subplots, ajusta el espaciado entre los subplots para evitar la superosición (tal y como ves en la figura), emplea subplots_adjust y los parámetros hspace y wspace.

# %%
fig, axs = plt.subplots(2, 2, figsize=(10, 8))

# Datos comunes
x = np.linspace(0, 10, 100)

# Primer subplot: Función sinusoidal
axs[0, 0].plot(x, np.sin(x))
axs[0, 0].set_ylim(-1.1, 1.1)
axs[0, 0].grid(True)

# Segundo subplot: Función coseno
axs[0, 1].plot(x, np.cos(x))
axs[0, 1].set_ylim(-1.1, 1.1)
axs[0, 1].grid(True)

# Tercer subplot: Función polinómica
axs[1,0].plot(x, np.tan(x))
axs[1, 0].set_ylim(-45, 25)
axs[1, 0].grid(True)


axs[1, 1].plot(x, np.exp(x/2))  
axs[1, 1].set_ylim(-0.1, 1.6)
axs[1, 1].set_title  # Título más descriptivo
axs[1, 1].set_xlabel('x')  # Añadido etiqueta del eje X
axs[1, 1].set_ylabel('f(x)')  # Añadido etiqueta del eje Y
axs[1, 1].grid(True, linestyle='--', alpha=0.7)  # Cuadrícula mejorada

# Ajuste de espacios
plt.subplots_adjust(wspace=0.3, hspace=0.4)

plt.show()

# Mostrar figura
plt.show()
