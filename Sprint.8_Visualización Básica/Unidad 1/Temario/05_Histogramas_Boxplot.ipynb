# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # Visualización con Matplotlib: Histogramas y diagramas de caja

# %% [markdown]
# Vamos a ver de forma sencilla como hacer los gráficos que nos generaban las funciones que empleamos en las visualizaciones analiticas del sprint anteior. En concreto, veremos los histogramas y los boxplots:

# %%
# %matplotlib inline
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np

data=np.random.randn(1000)

# %% [markdown]
# ### Histogramas

# %% [markdown]
# Tan sencillo como:

# %%
plt.hist(data);

# %%
fig = plt.figure(figsize=(4.5,3))
ax=plt.axes()
ax.hist(data);

# %% [markdown]
# La función ``hist()`` tiene muchas opciones para ajustar tanto el cálculo como la visualización; aquí tienes un ejemplo de un histograma más personalizado (en el que tocamos el número de columnas `bins`, la transparencia y el color):

# %%
plt.hist(data,
         bins=50,
         alpha = 1,
         color = "steelblue"
        )
# Out:
# (array([ 1.,  0.,  0.,  1.,  2.,  1.,  1.,  3.,  5.,  3.,  2.,  4.,  7.,
#         15., 12., 18., 16., 29., 29., 39., 39., 43., 33., 50., 50., 60.,
#         51., 58., 53., 36., 49., 43., 41., 32., 28., 33., 35., 18., 10.,
#         17., 11.,  5.,  3.,  3.,  2.,  5.,  1.,  1.,  0.,  2.]),
#  array([-3.510741  , -3.37833883, -3.24593666, -3.11353449, -2.98113232,
#         -2.84873014, -2.71632797, -2.5839258 , -2.45152363, -2.31912146,
#         -2.18671929, -2.05431712, -1.92191495, -1.78951278, -1.65711061,
#         -1.52470844, -1.39230627, -1.2599041 , -1.12750193, -0.99509976,
#         -0.86269759, -0.73029542, -0.59789325, -0.46549108, -0.33308891,
#         -0.20068674, -0.06828457,  0.0641176 ,  0.19651978,  0.32892195,
#          0.46132412,  0.59372629,  0.72612846,  0.85853063,  0.9909328 ,
#          1.12333497,  1.25573714,  1.38813931,  1.52054148,  1.65294365,
#          1.78534582,  1.91774799,  2.05015016,  2.18255233,  2.3149545 ,
#          2.44735667,  2.57975884,  2.71216101,  2.84456318,  2.97696535,
#          3.10936752]),
#  <BarContainer object of 50 artists>)

# %% [markdown]
# La transparencia es particularmente interesante para comparar histogramas o mostrar dicha comparación (y aprovecho para enseñarte un truco para cuando tengas argumentos repetidos que poner en tus llamadas a función):

# %%
x1 = np.random.normal(0, 0.8, 1000)
x2 = np.random.normal(-2, 1, 1000)
x3 = np.random.normal(3, 2, 1000)

kwargs = dict(alpha = 0.3, bins = 20)

plt.hist(x1, **kwargs)
plt.hist(x2, **kwargs)
plt.hist(x3, **kwargs);

# %% [markdown]
# Es también el momento de enseñarte a capturar los límites de esos bines:

# %%
fig = plt.Figure()
ax= plt.axes()
limites = ax.hist(x1, alpha = 0.3, bins=30)

# %% [markdown]
# Limites es una tupla en la que el primer valor son los conteos y el segundo los límites de las barras:

# %%
limites [0]
# Out:
# array([  1.,   0.,   3.,   3.,   5.,   5.,  12.,  16.,  23.,  34.,  58.,
#         42.,  73.,  74.,  98.,  78., 107.,  65.,  72.,  58.,  39.,  33.,
#         33.,  28.,  17.,  12.,   3.,   3.,   2.,   3.])

# %%
limites [1]
# Out:
# array([-2.7313742 , -2.55828242, -2.38519064, -2.21209886, -2.03900708,
#        -1.8659153 , -1.69282352, -1.51973174, -1.34663996, -1.17354819,
#        -1.00045641, -0.82736463, -0.65427285, -0.48118107, -0.30808929,
#        -0.13499751,  0.03809427,  0.21118605,  0.38427783,  0.55736961,
#         0.73046139,  0.90355316,  1.07664494,  1.24973672,  1.4228285 ,
#         1.59592028,  1.76901206,  1.94210384,  2.11519562,  2.2882874 ,
#         2.46137918])

# %% [markdown]
# ### Boxplots
#
# Los diagramas de caja eran esos diagramas en los que resumíamos las medidas de posición y añadíamos una posible formar de obtener valores anómalos, extremos o outliers. En forma de diagrama:

# %% [markdown]
# ```text
#      Q1-1.5IQR   Q1  mediana  Q3   Q3+1.5IQR
#                   |-----:-----|
#   o      |--------|     :     |--------|    o  o
#                   |-----:-----|
# flier             <----------->            fliers/outlier
#                        IQR
#
# ```

# %% [markdown]
# Donde IQR es el rango intercuartilico (la diferencia entre el valor de Q3 o tercer cuartil o percentil-75 y el valor de Q1 o primer cuartil, o percentil-25)

# %% [markdown]
# En matplotlib:

# %%
plt.boxplot(data, whis = 1.5)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1c0a2db6f60>,
#   <matplotlib.lines.Line2D at 0x1c0a2db7e90>],
#  'caps': [<matplotlib.lines.Line2D at 0x1c0a31541a0>,
#   <matplotlib.lines.Line2D at 0x1c0a3154440>],
#  'boxes': [<matplotlib.lines.Line2D at 0x1c0a183d430>],
#  'medians': [<matplotlib.lines.Line2D at 0x1c0a3154740>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1c0a3154a70>],
#  'means': []}

# %% [markdown]
# En el caso de matplotlib empleamos por defecto diagramas de caja verticales. Pero podemos cambiarlo:

# %%
plt.boxplot(data, vert = False)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1c0a33c7290>,
#   <matplotlib.lines.Line2D at 0x1c0a33c7590>],
#  'caps': [<matplotlib.lines.Line2D at 0x1c0a33c7830>,
#   <matplotlib.lines.Line2D at 0x1c0a33c79b0>],
#  'boxes': [<matplotlib.lines.Line2D at 0x1c0a33c6fc0>],
#  'medians': [<matplotlib.lines.Line2D at 0x1c0a33c7ce0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1c0a33c7f50>],
#  'means': []}

# %% [markdown]
# Y podemos mostrar varios juntos:

# %%
plt.boxplot([x1,x2,x3]);
