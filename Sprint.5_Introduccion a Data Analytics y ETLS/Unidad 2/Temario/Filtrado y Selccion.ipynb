# %% [markdown]
# # Filtrado y Selección
#
# En esta sesión vamos a tratar el tema del filtrado de forma que podamos obtener el conjunto de filas y columnas de un dataframe que cumplan una serie de condiciones. En la siguiente sesión, usaremos esto para hacer modificaciones selectivas en nuestro dataframe, lo que nos será muy útil en el futuro para tratar datos.
#
# ## Filtrado de Filas
#
# Como en casi todos los notebooks de esta unidad, jugaremos con el dataset de aviones. Ejecuta la siguiente celda:

# %%
import numpy as np
import pandas as pd

df_aviones = pd.read_csv("C:/Users/david/Repo_Prueba/DS_Online_Febr25_Exercises/02_Programacion_y_Herramientas_Avanzadas/Sprint_04/Unidad_02/Practica_Obligatoria/data/dataset_viajes.csv")
df_aviones
# Out:
#            Id_vuelo  Aircompany      Origen      Destino  Distancia  \
# 0    Air_PaGi_10737      Airnar       París      Ginebra      411.0
# 1    Fly_BaRo_10737        FlyQ        Bali         Roma    12738.0
# 2    Tab_GiLo_11380    TabarAir     Ginebra  Los Angeles     9103.0
# 3    Mol_PaCi_10737  MoldaviAir       París   Cincinnati     6370.0
# 4    Tab_CiRo_10747    TabarAir  Cincinnati         Roma     7480.0
# ..              ...         ...         ...          ...        ...
# 995  Pam_LoNu_10747   PamPangea     Londres   Nueva York     5566.0
# 996  Mol_MeLo_10747  MoldaviAir   Melbourne      Londres    16900.0
# 997  Mol_BaPa_10747  MoldaviAir        Bali        París    11980.0
# 998  Air_CaCi_10747      Airnar       Cádiz   Cincinnati     6624.0
# 999  Air_PaCi_10737      Airnar       París   Cincinnati     6370.0
#
#            avion         consumo_kg  duracion
# 0     Boeing 737                NaN      51.0
# 1     Boeing 737  33479.13254400001    1167.0
# 2    Airbus A380                NaN     626.0
# 3     Boeing 737           17027.01     503.0
# 4     Boeing 747          86115.744     518.0
# ..           ...                ...       ...
# 995   Boeing 747          62300,238     391.0
# 996   Boeing 747        194854.5664    1326.0
# 997   Boeing 747         128983.868     818.0
# 998   Boeing 747         72024.0768     461.0
# 999   Boeing 737          16872,219     503.0
#
# [1000 rows x 8 columns]

# %%
## Mirar el numero de vuelos para recordar algunos metodos de sesiones anteriores

# %%
df_aviones["Aircompany"].value_counts()
# Out:
# Aircompany
# TabarAir      229
# MoldaviAir    226
# PamPangea     192
# Airnar        180
# FlyQ          173
# Name: count, dtype: int64

# %%
## Filtrar/seleccionar solo las filas de dichos vuelos

resultado = df_aviones.loc[df_aviones["Aircompany"]=="FlyQ"]

# %%
resultado
# Out:
#            Id_vuelo Aircompany      Origen     Destino  Distancia  \
# 1    Fly_BaRo_10737       FlyQ        Bali        Roma    12738.0
# 33   Fly_RoNu_11320       FlyQ        Roma  Nueva York     6877.0
# 36   Fly_GiCi_10737       FlyQ     Ginebra  Cincinnati     6969.0
# 40   Fly_GiRo_10737       FlyQ     Ginebra        Roma      698.0
# 41   Fly_BaGi_10737       FlyQ        Bali     Ginebra    12383.0
# ..              ...        ...         ...         ...        ...
# 943  Fly_CiNu_10737       FlyQ  Cincinnati  Nueva York      911.0
# 945  Fly_BaBa_11380       FlyQ   Barcelona        Bali    13058.0
# 962  Fly_NuRo_11380       FlyQ  Nueva York        Roma     6877.0
# 974  Fly_NuGi_11380       FlyQ  Nueva York     Ginebra     6206.0
# 980  Fly_BaBa_10737       FlyQ   Barcelona        Bali    13058.0
#
#            avion         consumo_kg  duracion
# 1     Boeing 737  33479.13254400001    1167.0
# 33   Airbus A320       18131.238008     618.0
# 36    Boeing 737                NaN       NaN
# 40    Boeing 737          1763.9856      73.0
# 41    Boeing 737  31607.26077600001       NaN
# ..           ...                ...       ...
# 943   Boeing 737          2280.1419      89.0
# 945  Airbus A380      166407.809152    1070.0
# 962  Airbus A380  87447.93200000002     478.0
# 974  Airbus A380          75328.428     433.0
# 980   Boeing 737  33990.18292800001    1191.0
#
# [173 rows x 8 columns]

# %% [markdown]
# Si queremos mantener, por lo que fuera, la estructura completa con el resto de vuelos con un valor especial o nulo usamos where

# %%
### Usando where, sin cambiar valor

df_aviones.where(df_aviones["Aircompany"]=="FlyQ")
# Out:
#            Id_vuelo Aircompany Origen Destino  Distancia       avion  \
# 0               NaN        NaN    NaN     NaN        NaN         NaN
# 1    Fly_BaRo_10737       FlyQ   Bali    Roma    12738.0  Boeing 737
# 2               NaN        NaN    NaN     NaN        NaN         NaN
# 3               NaN        NaN    NaN     NaN        NaN         NaN
# 4               NaN        NaN    NaN     NaN        NaN         NaN
# ..              ...        ...    ...     ...        ...         ...
# 995             NaN        NaN    NaN     NaN        NaN         NaN
# 996             NaN        NaN    NaN     NaN        NaN         NaN
# 997             NaN        NaN    NaN     NaN        NaN         NaN
# 998             NaN        NaN    NaN     NaN        NaN         NaN
# 999             NaN        NaN    NaN     NaN        NaN         NaN
#
#             consumo_kg  duracion
# 0                  NaN       NaN
# 1    33479.13254400001    1167.0
# 2                  NaN       NaN
# 3                  NaN       NaN
# 4                  NaN       NaN
# ..                 ...       ...
# 995                NaN       NaN
# 996                NaN       NaN
# 997                NaN       NaN
# 998                NaN       NaN
# 999                NaN       NaN
#
# [1000 rows x 8 columns]

# %%
# Usando where, cambiando valor

df_aviones.where(df_aviones["Aircompany"]=="FlyQ","no usar")
# Out:
#            Id_vuelo Aircompany   Origen  Destino Distancia       avion  \
# 0           no usar    no usar  no usar  no usar   no usar     no usar
# 1    Fly_BaRo_10737       FlyQ     Bali     Roma   12738.0  Boeing 737
# 2           no usar    no usar  no usar  no usar   no usar     no usar
# 3           no usar    no usar  no usar  no usar   no usar     no usar
# 4           no usar    no usar  no usar  no usar   no usar     no usar
# ..              ...        ...      ...      ...       ...         ...
# 995         no usar    no usar  no usar  no usar   no usar     no usar
# 996         no usar    no usar  no usar  no usar   no usar     no usar
# 997         no usar    no usar  no usar  no usar   no usar     no usar
# 998         no usar    no usar  no usar  no usar   no usar     no usar
# 999         no usar    no usar  no usar  no usar   no usar     no usar
#
#             consumo_kg duracion
# 0              no usar  no usar
# 1    33479.13254400001   1167.0
# 2              no usar  no usar
# 3              no usar  no usar
# 4              no usar  no usar
# ..                 ...      ...
# 995            no usar  no usar
# 996            no usar  no usar
# 997            no usar  no usar
# 998            no usar  no usar
# 999            no usar  no usar
#
# [1000 rows x 8 columns]

# %% [markdown]
# Podemos hacer consultasmucho más complejas y asignandolas a variables intermedias

# %%
#Quedarme con los vuelos de los A380 de más de 1000km con destino Melbourne

vuelos_A380 = df_aviones["avion"]=="Airbus A380"
mayor_10km= df_aviones["Distancia"]>10000
a_Melbourne = df_aviones["Destino"] == "Melbourne"
condicion = vuelos_A380 & mayor_10km & a_Melbourne
df_aviones.loc[condicion]
# Out:
#            Id_vuelo  Aircompany      Origen    Destino  Distancia  \
# 7    Pam_PaMe_11380   PamPangea       París  Melbourne    16925.0
# 267  Mol_PaMe_11380  MoldaviAir       París  Melbourne    16925.0
# 329  Mol_CiMe_11380  MoldaviAir  Cincinnati  Melbourne    15262.0
# 519  Mol_CaMe_11380  MoldaviAir       Cádiz  Melbourne    20029.0
# 523  Pam_GiMe_11380   PamPangea     Ginebra  Melbourne    16674.0
# 714  Pam_LoMe_11380   PamPangea     Londres  Melbourne    16900.0
# 744  Pam_LoMe_11380   PamPangea     Londres  Melbourne    16900.0
# 829  Pam_NuMe_11380   PamPangea  Nueva York  Melbourne    16082.0
# 925  Pam_PaMe_11380   PamPangea       París  Melbourne    16925.0
#
#            avion     consumo_kg  duracion
# 7    Airbus A380    217722.6584    1328.0
# 267  Airbus A380    207548.7024       NaN
# 329  Airbus A380  199999.596992    1217.0
# 519  Airbus A380  248020.549088    1535.0
# 523  Airbus A380  216498.417408    1311.0
# 714  Airbus A380     213337.488    1326.0
# 744  Airbus A380      203178.56    1326.0
# 829  Airbus A380            NaN    1272.0
# 925  Airbus A380            NaN    1328.0

# %%
### Seleccionemos vuelos PamPangea con destino a Ginebra o salida en Nueva York

# %% [markdown]
# Y de igual manera, puedo usar where para conservar la estructura

# %%
company = df_aviones["Aircompany"] == "PamPangea"
destino = df_aviones ["Destino"] == "Ginebra"
de_NY = df_aviones ["Origen"] == "Nueva York"
condicion = company & (destino | de_NY)
df_aviones.loc[condicion]
# Out:
#            Id_vuelo Aircompany      Origen    Destino  Distancia        avion  \
# 8    Pam_NuBa_10737  PamPangea  Nueva York       Bali    16589.0   Boeing 737
# 39   Pam_MeGi_11380  PamPangea   Melbourne    Ginebra    16674.0  Airbus A380
# 46   Pam_NuMe_10747  PamPangea  Nueva York  Melbourne    16082.0   Boeing 747
# 47   Pam_NuPa_11380  PamPangea  Nueva York      París     5835.0  Airbus A380
# 53   Pam_PaGi_11380  PamPangea       París    Ginebra      411.0  Airbus A380
# 57   Pam_NuBa_10747  PamPangea  Nueva York       Bali    16589.0   Boeing 747
# 62   Pam_NuMe_10747  PamPangea  Nueva York  Melbourne    16082.0   Boeing 747
# 106  Pam_BaGi_10737  PamPangea        Bali    Ginebra    12383.0   Boeing 737
# 110  Pam_NuLo_11380  PamPangea  Nueva York    Londres        NaN  Airbus A380
# 116  Pam_NuLo_10737  PamPangea  Nueva York    Londres     5566.0   Boeing 737
# 119  Pam_LoGi_10737  PamPangea     Londres    Ginebra      739.0   Boeing 737
# 122  Pam_NuBa_10747  PamPangea  Nueva York       Bali    16589.0   Boeing 747
# 133  Pam_NuPa_10737  PamPangea  Nueva York      París     5835.0   Boeing 737
# 142  Pam_NuBa_11380  PamPangea  Nueva York       Bali    16589.0  Airbus A380
# 147  Pam_NuGi_10737  PamPangea  Nueva York    Ginebra     6206.0   Boeing 737
# 185  Pam_NuGi_11320  PamPangea  Nueva York    GiNeBra     6206.0  Airbus A320
# 237  Pam_NuPa_11320  PamPangea  Nueva York      París     5835.0  Airbus A320
# 255  Pam_MeGi_11380  PamPangea   Melbourne    Ginebra    16674.0  Airbus A380
# 261  Pam_NuGi_11380  PamPangea  Nueva York    Ginebra     6206.0  Airbus A380
# 269  Pam_NuGi_10737  PamPangea  Nueva York    Ginebra     6206.0   Boeing 737
# 275  Pam_NuBa_10747  PamPangea  Nueva York       Bali    16589.0   Boeing 747
# 298  Pam_MeGi_10737  PamPangea   Melbourne    Ginebra    16674.0   Boeing 737
# 358  Pam_BaGi_10747  PamPangea        Bali    Ginebra    12383.0   Boeing 747
# 373  Pam_PaGi_11320  PamPangea       París    Ginebra      411.0  Airbus A320
# 405  Pam_NuBa_10747  PamPangea  Nueva York       Bali        NaN   Boeing 747
# 407  Pam_PaGi_10737  PamPangea       París    Ginebra      411.0   Boeing 737
# 424  Pam_NuMe_10747  PamPangea  Nueva York  Melbourne    16082.0   Boeing 747
# 444  Pam_NuGi_11380  PamPangea  Nueva York    Ginebra     6206.0  Airbus A380
# 467  Pam_NuBa_10737  PamPangea  Nueva York       Bali    16589.0   Boeing 737
# 482  Pam_NuGi_10737  PamPangea  Nueva York    Ginebra     6206.0   Boeing 737
# 492  Pam_NuPa_10737  PamPangea  Nueva York      París     5835.0   Boeing 737
# 500  Pam_LoGi_10737  PamPangea     Londres    Ginebra        NaN   Boeing 737
# 511  Pam_NuMe_10737  PamPangea  Nueva York  Melbourne        NaN   Boeing 737
# 522  Pam_LoGi_11380  PamPangea     Londres    Ginebra      739.0  Airbus A380
# 524  Pam_MeGi_10747  PamPangea   Melbourne    Ginebra    16674.0   Boeing 747
# 528  Pam_NuLo_10737  PamPangea  Nueva York    Londres     5566.0   Boeing 737
# 586  Pam_NuPa_10747  PamPangea  Nueva York      París     5835.0   Boeing 747
# 591  Pam_NuMe_10747  PamPangea  Nueva York  Melbourne        NaN   Boeing 747
# 594  Pam_LoGi_11320  PamPangea     Londres    Ginebra      739.0  Airbus A320
# 600  Pam_NuLo_11320  PamPangea  Nueva York    Londres     5566.0  Airbus A320
# 618  Pam_MeGi_10747  PamPangea   Melbourne    Ginebra    16674.0   Boeing 747
# 638  Pam_LoGi_11380  PamPangea     Londres    Ginebra      739.0  Airbus A380
# 644  Pam_BaGi_10737  PamPangea        Bali    Ginebra    12383.0   Boeing 737
# 668  Pam_BaGi_10737  PamPangea        Bali    Ginebra    12383.0   Boeing 737
# 676  Pam_PaGi_10747  PamPangea       París    Ginebra        NaN   Boeing 747
# 690  Pam_MeGi_10747  PamPangea   Melbourne    Ginebra    16674.0   Boeing 747
# 705  Pam_NuLo_10737  PamPangea  Nueva York    Londres     5566.0   Boeing 737
# 729  Pam_NuLo_11380  PamPangea  Nueva York    Londres     5566.0  Airbus A380
# 733  Pam_BaGi_11380  PamPangea        Bali    Ginebra    12383.0  Airbus A380
# 767  Pam_PaGi_11380  PamPangea       París    Ginebra      411.0  Airbus A380
# 829  Pam_NuMe_11380  PamPangea  Nueva York  Melbourne    16082.0  Airbus A380
# 830  Pam_BaGi_11380  PamPangea        Bali    Ginebra        NaN  Airbus A380
# 833  Pam_NuGi_11320  PamPangea  Nueva York    GiNEbra     6206.0  Airbus A320
# 899  Pam_BaGi_11380  PamPangea        Bali    Ginebra    12383.0  Airbus A380
# 903  Pam_NuPa_11380  PamPangea  Nueva York      París     5835.0  Airbus A380
# 923  Pam_NuPa_11320  PamPangea  Nueva York      París     5835.0  Airbus A320
# 963  Pam_NuGi_11380  PamPangea  Nueva York    Ginebra     6206.0  Airbus A380
# 972  Pam_MeGi_10737  PamPangea   Melbourne    Ginebra    16674.0   Boeing 737
#
#             consumo_kg  duracion
# 8    45277.61846400001    1459.0
# 39                 NaN       NaN
# 46       183640.229344    1272.0
# 47           72174.282     409.0
# 53           5083.7412      47.0
# 57       191268,781184    1305.0
# 62       180074,399648    1272.0
# 106  32859.03348000001    1140.0
# 110  68203.53760000001     391.0
# 116         13660.6338       NaN
# 119          1849.6431      76.0
# 122      185751.412496    1305.0
# 133           14179.05     463.0
# 142      205422.781408    1305.0
# 147         15231.3858     491.0
# 185       17334.152368     569.0
# 237        16145.58504     542.0
# 255                NaN    1311.0
# 261          75328.428     433.0
# 269         15532.9974     491.0
# 275      185751.412496    1305.0
# 298  46352,38608000001    1466.0
# 358        143883,0302     845.0
# 373          1103,8227      49.0
# 405      187590.535392    1305.0
# 407          1008.7173      51.0
# 424                NaN    1272.0
# 444                NaN     433.0
# 467  42762,19521600001    1459.0
# 482         15985.4148     491.0
# 492           14179.05       NaN
# 500          1867.6008      76.0
# 511  43080.97622400001    1421.0
# 522            8542.84      69.0
# 524                NaN    1311.0
# 528         13931.1414     442.0
# 586          62823.111     409.0
# 591      194337.718432    1272.0
# 594          2021.8301      73.0
# 600                NaN     523.0
# 618      188551.726272    1311.0
# 638          8628,2684      69.0
# 644                NaN    1140.0
# 668       32546.090304       NaN
# 676  4468,885200000001      47.0
# 690      190400.272608    1311.0
# 705         14336.9028       NaN
# 729  70777.25600000001       NaN
# 733        147441.9044     845.0
# 767          5036.2296      47.0
# 829                NaN    1272.0
# 830        144578,9548     845.0
# 833       17496.153792     569.0
# 899        154599.2784     845.0
# 903                NaN     409.0
# 923        16602.53556     542.0
# 963         76763.2552     433.0
# 972       43402.688784    1466.0

# %% [markdown]
# De igual manera puedo usar where para conservar la estructura

# %%
df_aviones.where(condicion,"no usar").tail(20)
# Out:
#     Id_vuelo Aircompany   Origen  Destino Distancia    avion consumo_kg  \
# 980  no usar    no usar  no usar  no usar   no usar  no usar    no usar
# 981  no usar    no usar  no usar  no usar   no usar  no usar    no usar
# 982  no usar    no usar  no usar  no usar   no usar  no usar    no usar
# 983  no usar    no usar  no usar  no usar   no usar  no usar    no usar
# 984  no usar    no usar  no usar  no usar   no usar  no usar    no usar
# 985  no usar    no usar  no usar  no usar   no usar  no usar    no usar
# 986  no usar    no usar  no usar  no usar   no usar  no usar    no usar
# 987  no usar    no usar  no usar  no usar   no usar  no usar    no usar
# 988  no usar    no usar  no usar  no usar   no usar  no usar    no usar
# 989  no usar    no usar  no usar  no usar   no usar  no usar    no usar
# 990  no usar    no usar  no usar  no usar   no usar  no usar    no usar
# 991  no usar    no usar  no usar  no usar   no usar  no usar    no usar
# 992  no usar    no usar  no usar  no usar   no usar  no usar    no usar
# 993  no usar    no usar  no usar  no usar   no usar  no usar    no usar
# 994  no usar    no usar  no usar  no usar   no usar  no usar    no usar
# 995  no usar    no usar  no usar  no usar   no usar  no usar    no usar
# 996  no usar    no usar  no usar  no usar   no usar  no usar    no usar
# 997  no usar    no usar  no usar  no usar   no usar  no usar    no usar
# 998  no usar    no usar  no usar  no usar   no usar  no usar    no usar
# 999  no usar    no usar  no usar  no usar   no usar  no usar    no usar
#
#     duracion
# 980  no usar
# 981  no usar
# 982  no usar
# 983  no usar
# 984  no usar
# 985  no usar
# 986  no usar
# 987  no usar
# 988  no usar
# 989  no usar
# 990  no usar
# 991  no usar
# 992  no usar
# 993  no usar
# 994  no usar
# 995  no usar
# 996  no usar
# 997  no usar
# 998  no usar
# 999  no usar

# %% [markdown]
# ### Filtrado a todo el DataFraame

# %%
df_test = pd.DataFrame(np.random.randint(0,10,(4,3)),columns=["Protones","Neutrones","Quarks"])
df_test
# Out:
#    Protones  Neutrones  Quarks
# 0         1          2       2
# 1         6          7       8
# 2         4          1       2
# 3         0          2       3

# %%
df_test[df_test<6]
# Out:
#    Protones  Neutrones  Quarks
# 0       1.0        2.0     2.0
# 1       NaN        NaN     NaN
# 2       4.0        1.0     2.0
# 3       0.0        2.0     3.0

# %%
df_test.where(df_test < 6,"no usar")
# Out:
#   Protones Neutrones   Quarks
# 0        1         2        2
# 1  no usar   no usar  no usar
# 2        4         1        2
# 3        0         2        3
