# %% [markdown]
# # 0 Carga de datos y primera exploración

# %%
import numpy as np
import pandas as pd

df_viajes_aereos = pd.read_csv("C:/Users/david/Downloads/dataset_viajes.csv", index_col = "Id_vuelo")

# %% [markdown]
# Haz una primera exploración de los datos. Muestra la información general, la descripción de las variables numéricas, las columnas y muestra la distribución de datos de tres columnas escogidas por ti.

# %%
df = df_viajes_aereos.copy()

# %%
df
# Out:
#                 Aircompany      Origen      Destino  Distancia        avion  \
# Id_vuelo
# Air_PaGi_10737      Airnar       París      Ginebra      411.0   Boeing 737
# Fly_BaRo_10737        FlyQ        Bali         Roma    12738.0   Boeing 737
# Tab_GiLo_11380    TabarAir     Ginebra  Los Angeles     9103.0  Airbus A380
# Mol_PaCi_10737  MoldaviAir       París   Cincinnati     6370.0   Boeing 737
# Tab_CiRo_10747    TabarAir  Cincinnati         Roma     7480.0   Boeing 747
# ...                    ...         ...          ...        ...          ...
# Pam_LoNu_10747   PamPangea     Londres   Nueva York     5566.0   Boeing 747
# Mol_MeLo_10747  MoldaviAir   Melbourne      Londres    16900.0   Boeing 747
# Mol_BaPa_10747  MoldaviAir        Bali        París    11980.0   Boeing 747
# Air_CaCi_10747      Airnar       Cádiz   Cincinnati     6624.0   Boeing 747
# Air_PaCi_10737      Airnar       París   Cincinnati     6370.0   Boeing 737
#
#                        consumo_kg  duracion
# ...

# %%
df.head(10)
# Out:
#                 Aircompany      Origen      Destino  Distancia        avion  \
# Id_vuelo
# Air_PaGi_10737      Airnar       París      Ginebra      411.0   Boeing 737
# Fly_BaRo_10737        FlyQ        Bali         Roma    12738.0   Boeing 737
# Tab_GiLo_11380    TabarAir     Ginebra  Los Angeles     9103.0  Airbus A380
# Mol_PaCi_10737  MoldaviAir       París   Cincinnati     6370.0   Boeing 737
# Tab_CiRo_10747    TabarAir  Cincinnati         Roma     7480.0   Boeing 747
# Mol_CaMe_10737  MoldaviAir       Cádiz    Melbourne    20029.0   Boeing 737
# Mol_PaLo_11320  MoldaviAir       París      Londres      344.0  Airbus A320
# Pam_PaMe_11380   PamPangea       París    Melbourne    16925.0  Airbus A380
# Pam_NuBa_10737   PamPangea  Nueva York         Bali    16589.0   Boeing 737
# Air_GiCa_11380      Airnar     Ginebra        Cádiz        NaN  Airbus A380
#
#                        consumo_kg  duracion
# Id_vuelo
# Air_PaGi_10737                NaN      51.0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1000 entries, Air_PaGi_10737 to Air_PaCi_10737
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Aircompany  1000 non-null   object
#  1   Origen      1000 non-null   object
#  2   Destino     1000 non-null   object
#  3   Distancia   872 non-null    float64
#  4   avion       1000 non-null   object
#  5   consumo_kg  862 non-null    object
#  6   duracion    853 non-null    float64
# dtypes: float64(2), object(5)
# memory usage: 62.5+ KB

# %%
df.Origen.value_counts()
# Out:
# Origen
# Bali           134
# Ginebra        134
# Cincinnati     119
# Londres        112
# Nueva York     106
# París           94
# Melbourne       86
# Los Angeles     71
# Cádiz           55
# Roma            55
# Barcelona       34
# Name: count, dtype: int64

# %%
df.Destino.value_counts()
# Out:
# Destino
# Cincinnati     125
# Bali           122
# Londres        111
# París          111
# Ginebra        102
# Nueva York     102
# Roma            83
# Los Angeles     62
# Cádiz           58
# Melbourne       52
# Barcelona       21
# GinEbra          2
# GiNeBra          2
# GINEbRa          2
# GInEBrA          2
# GInebra          2
# BaRCelONa        2
# GINebra          2
# GInebRA          1
# GINebRa          1
# MelBOUrnE        1
# BARcelOnA        1
# GINEbRA          1
# MelbOUrnE        1
# MeLbourne        1
# GIneBra          1
# GIneBrA          1
# GinebrA          1
# GiNebrA          1
# GiNEbRa          1
# MeLboURnE        1
# MELboURnE        1
# MELBoURNe        1
# MElboUrNe        1
# MelboURNe        1
# BARCEloNA        1
# GInEBRa          1
# GInEbRa          1
# GINEBra          1
# MelBoUrne        1
# MelBourne        1
# GineBra          1
# MeLbOurne        1
# GINEBrA          1
# MelBouRne        1
# MELBoURne        1
# MELBourNe        1
# ...

# %% [markdown]
# # 1 Limpieza de Datos

# %% [markdown]
# Revisa los datos y contesta a las siguientes preguntas:
#
# 1.1 ¿Existen filas duplicadas?¿Cuántas?¿Hay alguna compañía que lo sufra más que otra o más o menos están igual?
#
# 1.2 ¿Hay columnas con datos faltantes o nulos? ¿Cuáles? ¿Qué porcentaje representan esos valores del total? (Pista: Para contestar a esta pregunta explora los argumentos del método value_counts)
#
# 1.3 ¿Hay alguna columna "sucia"? Es decir, ¿existe alguna columna cuyos datos tuvieramos que modificar para tener una mejor comprensión y manajeabilidad de los mismos? ¿Cuáles?

# %%
df.duplicated(keep=False)
# Out:
# Id_vuelo
# Air_PaGi_10737    False
# Fly_BaRo_10737    False
# Tab_GiLo_11380     True
# Mol_PaCi_10737    False
# Tab_CiRo_10747    False
#                   ...
# Pam_LoNu_10747    False
# Mol_MeLo_10747    False
# Mol_BaPa_10747    False
# Air_CaCi_10747    False
# Air_PaCi_10737    False
# Length: 1000, dtype: bool

# %%
len(df[df.duplicated(keep = False)]) # keep = "first", keep = False
# Out:
# 54

# %%
df.loc[df.duplicated(keep = False), "Aircompany"].value_counts()
# Out:
# Aircompany
# MoldaviAir    20
# TabarAir      14
# PamPangea     10
# Airnar         6
# FlyQ           4
# Name: count, dtype: int64

# %%
df.loc[df.duplicated(keep = False), "Aircompany"].value_counts()/df.Aircompany.value_counts() * 100
# Out:
# Aircompany
# Airnar        3.333333
# FlyQ          2.312139
# MoldaviAir    8.849558
# PamPangea     5.208333
# TabarAir      6.113537
# Name: count, dtype: float64

# %%
df.columns = [col.lower() for col in df.columns]

# %%
df
# Out:
#                 aircompany      origen      destino  distancia        avion  \
# Id_vuelo
# Air_PaGi_10737      Airnar       París      Ginebra      411.0   Boeing 737
# Fly_BaRo_10737        FlyQ        Bali         Roma    12738.0   Boeing 737
# Tab_GiLo_11380    TabarAir     Ginebra  Los Angeles     9103.0  Airbus A380
# Mol_PaCi_10737  MoldaviAir       París   Cincinnati     6370.0   Boeing 737
# Tab_CiRo_10747    TabarAir  Cincinnati         Roma     7480.0   Boeing 747
# ...                    ...         ...          ...        ...          ...
# Pam_LoNu_10747   PamPangea     Londres   Nueva York     5566.0   Boeing 747
# Mol_MeLo_10747  MoldaviAir   Melbourne      Londres    16900.0   Boeing 747
# Mol_BaPa_10747  MoldaviAir        Bali        París    11980.0   Boeing 747
# Air_CaCi_10747      Airnar       Cádiz   Cincinnati     6624.0   Boeing 747
# Air_PaCi_10737      Airnar       París   Cincinnati     6370.0   Boeing 737
#
#                        consumo_kg  duracion
# ...

# %%
# nulos
df['distancia'].value_counts(normalize=True, dropna=False)
# Out:
# distancia
# NaN        0.128
# 6206.0     0.041
# 11980.0    0.037
# 12383.0    0.037
# 6877.0     0.034
# 739.0      0.031
# 16900.0    0.029
# 6969.0     0.029
# 15011.0    0.028
# 9103.0     0.028
# 12553.0    0.026
# 5566.0     0.026
# 3073.0     0.026
# 6370.0     0.026
# 1447.0     0.025
# 344.0      0.024
# 7480.0     0.024
# 911.0      0.022
# 16589.0    0.022
# 411.0      0.022
# 2779.0     0.021
# 16925.0    0.021
# 6284.0     0.020
# 6624.0     0.018
# 15262.0    0.018
# 12738.0    0.016
# 12798.0    0.016
# 10077.0    0.015
# 1716.0     0.015
# 20029.0    0.014
# 1433.0     0.014
# 16674.0    0.014
# 13058.0    0.014
# 698.0      0.013
# 8785.0     0.012
# 5835.0     0.012
# 6170.0     0.011
# 12845.0    0.011
# 859.0      0.010
# 3944.0     0.010
# 660.0      0.009
# 16082.0    0.007
# 6763.0     0.007
# 1725.0     0.006
# 9099.0     0.006
# 9373.0     0.005
# Name: proportion, dtype: float64

# %%
#1.2
con_nulos = ["distancia","duracion","consumo_kg"]

for col in con_nulos:
    print(f"{col}: ",end = "")
    print((df[col].value_counts(normalize = True, dropna = False) * 100)[np.nan])
# Out:
# distancia: 12.8
# duracion: 14.7
# consumo_kg: 13.8

# %%
df.isnull()
# Out:
#                 aircompany  origen  destino  distancia  avion  consumo_kg  \
# Id_vuelo
# Air_PaGi_10737       False   False    False      False  False        True
# Fly_BaRo_10737       False   False    False      False  False       False
# Tab_GiLo_11380       False   False    False      False  False        True
# Mol_PaCi_10737       False   False    False      False  False       False
# Tab_CiRo_10747       False   False    False      False  False       False
# ...                    ...     ...      ...        ...    ...         ...
# Pam_LoNu_10747       False   False    False      False  False       False
# Mol_MeLo_10747       False   False    False      False  False       False
# Mol_BaPa_10747       False   False    False      False  False       False
# Air_CaCi_10747       False   False    False      False  False       False
# Air_PaCi_10737       False   False    False      False  False       False
#
#                 duracion
# Id_vuelo
# Air_PaGi_10737     False
# ...

# %%
df.isnull().sum()
# Out:
# aircompany      0
# origen          0
# destino         0
# distancia     128
# avion           0
# consumo_kg    138
# duracion      147
# dtype: int64

# %%
df.isnull().sum()/len(df) * 100
# Out:
# aircompany     0.0
# origen         0.0
# destino        0.0
# distancia     12.8
# avion          0.0
# consumo_kg    13.8
# duracion      14.7
# dtype: float64

# %%
# 1.3 "sucios":
#def tipo(valor):
#    return type(valor)

#df["consumo_kg"].apply(tipo).value_counts()

df["consumo_kg"].apply(type).value_counts()
# Out:
# consumo_kg
# <class 'str'>      862
# <class 'float'>    138
# Name: count, dtype: int64

# %%
def muestra_valor(valor):
    if type(valor) == str:
        print(valor)
    else:
        print("Numero")

df.consumo_kg.apply(muestra_valor)
# Out:
# Numero
# 33479.13254400001
# Numero
# 17027.01
# 86115.744
# 53148.15324000001
# 915.2464
# 217722.6584
# 45277.61846400001
# Numero
# 7915,433400000001
# 156721.6944
# 32758.18
# 8542.84
# 21087.85536
# Numero
# 51629.634576
# 104801.0184
# 46622.41740000001
# 16200.1424
# 156072.12192
# 146010.4296
# 33310.13868
# Numero
# 16803.358
# 33740,9254
# 7158.148200000001
# Numero
# 3813,7216
# 1751.98
# 33960.26088000001
# 144578.9548
# 20892.59744
# 18131.238008
# 192980.9648
# 24078.9822
# Numero
# 7114.795799999999
# 106741.778
# Numero
# 1763.9856
# 31607.26077600001
# 915.2464
# 1822,26
# 27357.200832
# Numero
# 183640.229344
# 72174.282
# 199439,5936
# 34607.12299200001
# 153234.446976
# 78055.432
# 24475.345336
# 5083.7412
# 70133.8264
# 9797.9258
# 18191,8776
# 191268,781184
# 18382.221
# 89062.864
# 189491.65872
# 35378.8344
# 180074,399648
# 1854.89
# 75328.428
# 70336.812
# Numero
# 18155.85408
# 138602.919
# 25445.970368
# 90792.24
# 88198.176
# 191296.341184
# 18555.715152
# ...

# %%
col_limpiar = ["destino","consumo_kg"]

# %%
df_2 = df.copy()
df.drop_duplicates(keep = "last", inplace = True)

# %% [markdown]
# 3. Vamos con los nulos o nan localizados en 1.2. Elimina las filas que tengan más de dos nulos, las podemos considerar demasiado ruidosas y las quitamos.

# %%
con_nulos
# Out:
# ['distancia', 'duracion', 'consumo_kg']

# %%
#df.dropna(subset = con_nulos, how = "any", axis = 1)

# %%
con_nulos
# Out:
# ['distancia', 'duracion', 'consumo_kg']

# %%
df.dropna(subset = con_nulos, how = "any", axis = 0) # axis 0 is rows
# Out:
#                 aircompany      origen     destino  distancia        avion  \
# Id_vuelo
# Fly_BaRo_10737        FlyQ        Bali        Roma    12738.0   Boeing 737
# Mol_PaCi_10737  MoldaviAir       París  Cincinnati     6370.0   Boeing 737
# Tab_CiRo_10747    TabarAir  Cincinnati        Roma     7480.0   Boeing 747
# Mol_PaLo_11320  MoldaviAir       París     Londres      344.0  Airbus A320
# Pam_PaMe_11380   PamPangea       París   Melbourne    16925.0  Airbus A380
# ...                    ...         ...         ...        ...          ...
# Pam_LoNu_10747   PamPangea     Londres  Nueva York     5566.0   Boeing 747
# Mol_MeLo_10747  MoldaviAir   Melbourne     Londres    16900.0   Boeing 747
# Mol_BaPa_10747  MoldaviAir        Bali       París    11980.0   Boeing 747
# Air_CaCi_10747      Airnar       Cádiz  Cincinnati     6624.0   Boeing 747
# Air_PaCi_10737      Airnar       París  Cincinnati     6370.0   Boeing 737
#
#                        consumo_kg  duracion
# Id_vuelo
# ...

# %%
# con_nulos.index.to_list()

# %%
condicion = (df.distancia.isna()) & (df.duracion.isna()) & (df.consumo_kg.isna())
con_nulos = df[condicion]
#df.drop(labels = df[condicion].index) # No usar si el indice no es único
df = df[condicion == False].copy()

print(len(df.dropna(subset = con_nulos.index.to_list(), how = "any", axis = 1) ))
print(len(df.dropna(thresh= 5))) # thresh = numero_de_columnas - numero_de_nulos_que_permito   7 - 2 = 5
# Out:
# 970
# 970

# %%
df.index.value_counts() # hay índices repetidos
# Out:
# Id_vuelo
# Tab_GiLo_10747    10
# Tab_LoGi_11380     9
# Fly_BaBa_11380     8
# Fly_BaRo_10747     7
# Tab_LoRo_10747     7
#                   ..
# Fly_CiNu_11320     1
# Fly_CiRo_11320     1
# Air_GiCa_11380     1
# Tab_LoCi_11380     1
# Air_CaCi_10747     1
# Name: count, Length: 418, dtype: int64

# %% [markdown]
# 4. Ahora con los nulos en las columnas numéricas, ¿hay alguna columna que creas que puedes reconstruir completamente? ¿Cuál?

# %%
#"duracion"
#"distancia" -> origen y destino, todos los vuelos de París a Cádiz, en teoría recorren la misma distancia
#"consumo_kg"

# %%
# Lo primero no hagas ninguna suposición con columnas sucias, limpia

# %%
#def limpia_destino(destino):
#    return destino.capitalize()

# %%
#df["destino"] = df.destino.apply(limpia_destino)
df["destino"] = df.destino.apply(str.capitalize)

# %%
df.destino.value_counts()
# Out:
# destino
# Ginebra        128
# Cincinnati     122
# Bali           117
# París          108
# Londres        105
# Nueva york      99
# Roma            82
# Melbourne       69
# Los angeles     60
# Cádiz           54
# Barcelona       26
# Name: count, dtype: int64

# %%
#df[df.distancia.isna() == False].groupby(["origen","destino"])["distancia"].nunique()

# %%
(df[df.distancia.isna() == False].groupby(["origen","destino"])["distancia"].nunique() > 1).sum() == 0
# compruebo que no hay origen-destino con más de una distancia
# Out:
# np.True_

# %%
df["distancia_corregida"] = df.groupby(["origen","destino"])["distancia"].transform("mean")

# %%
df.loc[df.distancia.isna(),"distancia"] = df.loc[df.distancia.isna(),"distancia_corregida"]

# %%
df.groupby(["origen","destino"])["distancia"].transform("mean") # explicación
#[5,5,5,5,5,5,5,5] -> [5]
# Out:
# Id_vuelo
# Air_PaGi_10737      411.0
# Fly_BaRo_10737    12738.0
# Mol_PaCi_10737     6370.0
# Tab_CiRo_10747     7480.0
# Mol_CaMe_10737    20029.0
#                    ...
# Pam_LoNu_10747     5566.0
# Mol_MeLo_10747    16900.0
# Mol_BaPa_10747    11980.0
# Air_CaCi_10747     6624.0
# Air_PaCi_10737     6370.0
# Name: distancia, Length: 970, dtype: float64

# %% [markdown]
# 5. Sustituye los valores nulos por valores medios en las columnas numéricas que no puedas reconstruir. Se valorará hacerlo con más precisión que utilizar la media global, ¿se te ocurre como hacerlo más preciso?

# %%
media_duracion = df.duracion.mean()
df.loc[df.duracion.isna(),"duracion"] = media_duracion

# %%
def limpiar_consumo(valor):
    if type(valor) == str:
        return float(valor.replace(",","."))
    else:
        return valor

df["consumo_kg"] = df.consumo_kg.apply(limpiar_consumo)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 970 entries, Air_PaGi_10737 to Air_PaCi_10737
# Data columns (total 8 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   aircompany           970 non-null    object
#  1   origen               970 non-null    object
#  2   destino              970 non-null    object
#  3   distancia            970 non-null    float64
#  4   avion                970 non-null    object
#  5   consumo_kg           838 non-null    float64
#  6   duracion             970 non-null    float64
#  7   distancia_corregida  970 non-null    float64
# dtypes: float64(4), object(4)
# memory usage: 100.5+ KB

# %%
media_consumo = df.consumo_kg.mean()
df.loc[df.consumo_kg.isna(), "consumo_kg"] = media_consumo

# %% [markdown]
# 6. En el caso de las columna no numéricas con nulos, ¿crees que puedes reconstruirlas? Si no es así, bórralas. [Se puede, pero no es sencillo]

# %%
# se podría sacar la compaía con el id del vuelo
# el resto de campos no numéricos no son triviales

df
# Out:
#                 aircompany      origen     destino  distancia       avion  \
# Id_vuelo
# Air_PaGi_10737      Airnar       París     Ginebra      411.0  Boeing 737
# Fly_BaRo_10737        FlyQ        Bali        Roma    12738.0  Boeing 737
# Mol_PaCi_10737  MoldaviAir       París  Cincinnati     6370.0  Boeing 737
# Tab_CiRo_10747    TabarAir  Cincinnati        Roma     7480.0  Boeing 747
# Mol_CaMe_10737  MoldaviAir       Cádiz   Melbourne    20029.0  Boeing 737
# ...                    ...         ...         ...        ...         ...
# Pam_LoNu_10747   PamPangea     Londres  Nueva york     5566.0  Boeing 747
# Mol_MeLo_10747  MoldaviAir   Melbourne     Londres    16900.0  Boeing 747
# Mol_BaPa_10747  MoldaviAir        Bali       París    11980.0  Boeing 747
# Air_CaCi_10747      Airnar       Cádiz  Cincinnati     6624.0  Boeing 747
# Air_PaCi_10737      Airnar       París  Cincinnati     6370.0  Boeing 737
#
#                    consumo_kg     duracion  distancia_corregida
# ...

# %%
df.aircompany.isna().sum() # no hay nulos
# Out:
# np.int64(0)

# %%
df.dtypes
# Out:
# aircompany              object
# origen                  object
# destino                 object
# distancia              float64
# avion                   object
# consumo_kg             float64
# duracion               float64
# distancia_corregida    float64
# dtype: object

# %%
df.dtypes[df.dtypes == object]
# Out:
# aircompany    object
# origen        object
# destino       object
# avion         object
# dtype: object

# %%
df.dtypes[df.dtypes == object].index
# Out:
# Index(['aircompany', 'origen', 'destino', 'avion'], dtype='object')

# %%
df.loc[:,df.dtypes[df.dtypes == object].index]
# Out:
#                 aircompany      origen     destino       avion
# Id_vuelo
# Air_PaGi_10737      Airnar       París     Ginebra  Boeing 737
# Fly_BaRo_10737        FlyQ        Bali        Roma  Boeing 737
# Mol_PaCi_10737  MoldaviAir       París  Cincinnati  Boeing 737
# Tab_CiRo_10747    TabarAir  Cincinnati        Roma  Boeing 747
# Mol_CaMe_10737  MoldaviAir       Cádiz   Melbourne  Boeing 737
# ...                    ...         ...         ...         ...
# Pam_LoNu_10747   PamPangea     Londres  Nueva york  Boeing 747
# Mol_MeLo_10747  MoldaviAir   Melbourne     Londres  Boeing 747
# Mol_BaPa_10747  MoldaviAir        Bali       París  Boeing 747
# Air_CaCi_10747      Airnar       Cádiz  Cincinnati  Boeing 747
# Air_PaCi_10737      Airnar       París  Cincinnati  Boeing 737
#
# [970 rows x 4 columns]

# %%
df.loc[:,df.dtypes[df.dtypes == object].index].isna()
# Out:
#                 aircompany  origen  destino  avion
# Id_vuelo
# Air_PaGi_10737       False   False    False  False
# Fly_BaRo_10737       False   False    False  False
# Mol_PaCi_10737       False   False    False  False
# Tab_CiRo_10747       False   False    False  False
# Mol_CaMe_10737       False   False    False  False
# ...                    ...     ...      ...    ...
# Pam_LoNu_10747       False   False    False  False
# Mol_MeLo_10747       False   False    False  False
# Mol_BaPa_10747       False   False    False  False
# Air_CaCi_10747       False   False    False  False
# Air_PaCi_10737       False   False    False  False
#
# [970 rows x 4 columns]

# %%
df.loc[:,df.dtypes[df.dtypes == object].index].isna().any() # ninguna columna categórica tiene nulos
# Out:
# aircompany    False
# origen        False
# destino       False
# avion         False
# dtype: bool

# %% [markdown]
# 7. Ahora sobre el DataFrame resultante, corrije las columnas que tengan valores "sucios" (comas equivocadas, valores extraños que no nulos, etc)

# %%
df.describe(include='all')
# 5 compañías, 11 orígenes, 11 destinos, 4 aviones, tiene buena pinta
# Out:
#        aircompany origen  destino     distancia        avion     consumo_kg  \
# count         970    970      970    970.000000          970     970.000000
# unique          5     11       11           NaN            4            NaN
# top      TabarAir   Bali  Ginebra           NaN  Airbus A380            NaN
# freq          222    130      128           NaN          279            NaN
# mean          NaN    NaN      NaN   8151.655670          NaN   66630.083667
# std           NaN    NaN      NaN   5563.425826          NaN   62105.600230
# min           NaN    NaN      NaN    344.000000          NaN     835.920000
# 25%           NaN    NaN      NaN   3073.000000          NaN   16873.719525
# 50%           NaN    NaN      NaN   6877.000000          NaN   48100.235200
# 75%           NaN    NaN      NaN  12553.000000          NaN   85395.338400
# max           NaN    NaN      NaN  20029.000000          NaN  264876.314560
#
#            duracion  distancia_corregida
# ...

# %% [markdown]
# # 2 Análisis de Datos
# Una vez "limpios" ya podemos analizar los datos y/o manipularlos. De hecho, nos piden que:
#
# Clasifiquemos los vuelos en Larga Distancia (LD), Media Distancia (MD) y Regionales (R). Con los siguientes límites: más de 9000km, entre 1500 y 9000 kms y resto de vuelos. Añade una columna al DataFrame que tenga esa clasificación por vuelo.º

# %%
def distancia(x):
    if x > 9000:
        return "LD"
    elif x > 1500:
        return "MD"
    else:
        return "R"

df['tipo_vuelo'] = df.distancia.apply(distancia)
df
# Out:
#                 aircompany      origen     destino  distancia       avion  \
# Id_vuelo
# Air_PaGi_10737      Airnar       París     Ginebra      411.0  Boeing 737
# Fly_BaRo_10737        FlyQ        Bali        Roma    12738.0  Boeing 737
# Mol_PaCi_10737  MoldaviAir       París  Cincinnati     6370.0  Boeing 737
# Tab_CiRo_10747    TabarAir  Cincinnati        Roma     7480.0  Boeing 747
# Mol_CaMe_10737  MoldaviAir       Cádiz   Melbourne    20029.0  Boeing 737
# ...                    ...         ...         ...        ...         ...
# Pam_LoNu_10747   PamPangea     Londres  Nueva york     5566.0  Boeing 747
# Mol_MeLo_10747  MoldaviAir   Melbourne     Londres    16900.0  Boeing 747
# Mol_BaPa_10747  MoldaviAir        Bali       París    11980.0  Boeing 747
# Air_CaCi_10747      Airnar       Cádiz  Cincinnati     6624.0  Boeing 747
# Air_PaCi_10737      Airnar       París  Cincinnati     6370.0  Boeing 737
#
# ...

# %% [markdown]
# 2. Crea ahora una columna que recoja el índice de contaminación de cada viaje calculado como el consumo de keroseno por kilometro recorrdio. Llama IC a esa columna.

# %%
df['IC'] = df.consumo_kg / df.distancia
df
# Out:
#                 aircompany      origen     destino  distancia       avion  \
# Id_vuelo
# Air_PaGi_10737      Airnar       París     Ginebra      411.0  Boeing 737
# Fly_BaRo_10737        FlyQ        Bali        Roma    12738.0  Boeing 737
# Mol_PaCi_10737  MoldaviAir       París  Cincinnati     6370.0  Boeing 737
# Tab_CiRo_10747    TabarAir  Cincinnati        Roma     7480.0  Boeing 747
# Mol_CaMe_10737  MoldaviAir       Cádiz   Melbourne    20029.0  Boeing 737
# ...                    ...         ...         ...        ...         ...
# Pam_LoNu_10747   PamPangea     Londres  Nueva york     5566.0  Boeing 747
# Mol_MeLo_10747  MoldaviAir   Melbourne     Londres    16900.0  Boeing 747
# Mol_BaPa_10747  MoldaviAir        Bali       París    11980.0  Boeing 747
# Air_CaCi_10747      Airnar       Cádiz  Cincinnati     6624.0  Boeing 747
# Air_PaCi_10737      Airnar       París  Cincinnati     6370.0  Boeing 737
#
# ...

# %%
df[['aircompany', 'IC']].nlargest(5, 'IC')
# Out:
#                aircompany          IC
# Id_vuelo
# Air_PaGi_10737     Airnar  162.116992
# Air_PaGi_11380     Airnar  162.116992
# Pam_GiPa_10747  PamPangea  162.116992
# Fly_GiBa_10747       FlyQ  100.954672
# Fly_BaGi_11380       FlyQ  100.954672

# %%
df[["aircompany", "tipo_vuelo", "IC"]].groupby(["tipo_vuelo", "aircompany"]).max().sort_values(by=["IC"], ascending=[False])
# Out:
#                                IC
# tipo_vuelo aircompany
# R          Airnar      162.116992
#            PamPangea   162.116992
#            FlyQ        100.954672
#            TabarAir     95.458573
#            MoldaviAir   46.047052
# MD         MoldaviAir   38.828720
#            Airnar       38.626135
#            TabarAir     21.682422
# LD         MoldaviAir   13.224640
#            PamPangea    13.224640
#            FlyQ         13.104416
#            Airnar       12.743744
# MD         FlyQ         12.716000
# LD         TabarAir     12.716000
# MD         PamPangea    12.716000

# %% [markdown]
# 5. Obtener los destinos con vuelos más contaminantes (utiliza el IC acumulado por destino y divídelo por el número de viajes a ese destino)

# %%
df[['destino', 'IC']].groupby(["destino"]).sum()
# Out:
#                       IC
# destino
# Bali          968.771554
# Barcelona     395.704040
# Cincinnati   1065.728062
# Cádiz         585.426324
# Ginebra      1561.337553
# Londres      1153.351698
# Los angeles   487.012953
# Melbourne     537.529866
# Nueva york    835.647997
# París        1068.338669
# Roma          882.960790

# %%
df[['destino', 'IC']].groupby(["destino"]).count()
# Out:
#               IC
# destino
# Bali         117
# Barcelona     26
# Cincinnati   122
# Cádiz         54
# Ginebra      128
# Londres      105
# Los angeles   60
# Melbourne     69
# Nueva york    99
# París        108
# Roma          82
